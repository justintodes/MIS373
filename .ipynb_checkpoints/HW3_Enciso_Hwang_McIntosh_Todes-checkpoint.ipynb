# %%
from pandas import Series, DataFrame
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Special packages
import statsmodels.api as sm
import numpy as np
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
# Out:
# /Users/justintodes/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # Q1: Read in data file

# %% [markdown]
# Read in .dat file of Clinton voter data, separate into columns

# %%
df = pd.read_csv('http://www.stat.ufl.edu/~winner/data/clinton1.dat', sep = "\s+\s", header=None)
df.columns = ['County', 'percentVoting', 'medAge', 'meanSavings', 'Income', 'percentPoverty', 'percentVeterans', 'percentFemale', 'popDensity', 'percentNursing', 'crimeIndex']
df.set_index('County', inplace=True)
df
# Out:
# /Users/justintodes/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#                  percentVoting  medAge  meanSavings  Income  percentPoverty  \
# County
# Autauga, AL              30.92    31.7        57623   15768            15.2
# Baldwin, AL              26.24    35.5        84935   16954            13.6
# Barbour, AL              46.36    32.8        83656   15532            25.0
# Blount, AL               32.92    34.5        61249   14820            15.0
# Bullock, AL              67.67    31.7        75725   11120            33.0
# Butler, AL               47.43    33.5        75887   12015            27.1
# Calhoun, AL              38.44    32.7        76073   15162            18.0
# Chambers, AL             45.36    34.8        40498   13887            18.8
# Cherokee, AL             53.61    36.3        56386   13936            15.4
# Chilton, AL              34.19    34.0        52230   14036            18.6
# Choctaw, AL              52.13    32.9        81367   13423            25.0
# Clarke, AL               42.87    31.7        87444   13750            24.4
# Cleburne, AL             40.94    34.1        63458   14168            15.6
# Coffee, AL               37.19    34.1        79268   17318            14.9
# Colbert, AL              54.40    35.7        71629   15705            15.3
# Conecuh, AL              50.02    34.5        49065   12876            27.4
# Covington, AL            35.84    36.2       104307   13921            21.6
# Crenshaw, AL             45.44    35.9        77907   13247            22.8
# Cullman, AL              35.98    34.8        67879   15261            15.4
# Dale, AL                 32.29    29.1        43261   14569            17.2
# Dallas, AL               56.38    31.1        68101   13574            34.2
# De Kalb, AL              38.20    34.9        64579   14294            17.3
# Elmore, AL               30.52    32.9        55540   14789            15.9
# Escambia, AL             37.50    33.9        90379   13184            24.4
# Etowah, AL               48.43    36.0        69920   15324            17.9
# Fayette, AL              45.22    35.6        83058   13404            18.6
# Franklin, AL             50.20    35.8       107673   14777            18.1
# Geneva, AL               36.71    36.4        89634   15339            19.4
# Greene, AL               79.18    31.3        27496   11165            38.8
# Hale, AL                 57.80    31.8        65003   11509            31.4
# ...                        ...     ...          ...     ...             ...
# Vernon, WI               44.61    36.2        77195   13491            13.5
# Vilas, WI                33.42    42.9        97618   15453            13.0
# Walworth, WI             32.14    33.1        81549   17731             7.9
# Washburn, WI             40.07    38.0        89176   14020            13.9
# Washington, WI           26.64    32.5        61535   20736             3.9
# Waukesha, WI             28.06    34.0        74506   25172             3.5
# Waupaca, WI              28.78    35.0       111119   17084             8.7
# Waushara, WI             32.94    38.6        72546   15261            14.6
# Winnebago, WI            35.19    32.5        63849   19659             7.7
# Wood, WI                 36.25    33.3        85696   19082             9.0
# Albany, WY               44.40    26.5        62209   15251            14.9
# Big Horn, WY             25.54    36.1        79941   14843            14.0
# Campbell, WY             24.15    29.2        89979   19679             8.7
# Carbon, WY               40.99    32.8       100736   18687            11.2
# Converse, WY             27.51    31.9        91132   16479            12.1
# Crook, WY                21.17    33.4       113381   19602            10.3
# Fremont, WY              34.30    32.9        64844   14797            18.4
# Goshen, WY               32.98    34.6       102320   17670            18.0
# Hot Springs, WY          30.85    38.6       104738   18294            13.3
# Johnson, WY              20.85    37.6       127314   18504            12.9
# Laramie, WY              38.23    31.9        64185   19329            11.5
# Natrona, WY              35.83    32.8        93827   21417            13.6
# Niobrara, WY             22.94    38.6       116712   19493            16.0
# Park, WY                 24.72    33.9       121587   18750            12.2
# Platte, WY               34.51    36.3       103845   17003            14.0
# Sheridan, WY             35.81    36.3        87232   22250            11.6
# Sublette, WY             20.83    35.4        83020   18748             7.9
# Sweetwater, WY           43.09    30.4       104346   19086             7.7
# Washakie, WY             28.08    34.6       114176   17608            11.7
# Weston, WY               24.02    34.4       132959   19265             9.4
#
#                  percentVeterans  percentFemale  popDensity  percentNursing  \
# County
# Autauga, AL                10.74          51.41        60.4            2.36
# Baldwin, AL                 9.73          51.34        66.5            5.40
# Barbour, AL                 8.82          53.03        28.8            7.02
# Blount, AL                  9.67          51.15        62.4            2.36
# Bullock, AL                 7.08          50.76        17.6            2.91
# Butler, AL                  9.48          53.25        28.1            7.98
# Calhoun, AL                11.95          51.66       190.8            4.81
# Chambers, AL               10.52          52.77        62.1            6.15
# Cherokee, AL                9.29          50.82        35.8            5.61
# Chilton, AL                 9.48          51.41        47.8            3.58
# Choctaw, AL                 9.94          52.54        17.6            4.16
# Clarke, AL                  8.79          52.18        22.4            5.07
# Cleburne, AL                8.58          50.71        23.2            5.00
# Coffee, AL                 10.40          50.99        60.5            5.72
# Colbert, AL                11.87          51.97        88.0            5.43
# Conecuh, AL                 8.90          52.67        16.6            3.62
# Covington, AL              11.67          52.74        35.7            4.82
# Crenshaw, AL                8.99          52.61        22.1           10.07
# Cullman, AL                10.07          51.40        94.4            6.43
# Dale, AL                   10.15          49.65        88.9            4.71
# Dallas, AL                 10.31          54.38        48.9            5.48
# De Kalb, AL                 9.26          51.71        71.9            7.10
# Elmore, AL                 10.45          49.22        84.3            5.29
# Escambia, AL               11.08          50.63        38.0            2.72
# Etowah, AL                 12.35          52.60       186.8            9.34
# Fayette, AL                 9.34          52.22        28.8           11.16
# Franklin, AL                8.84          52.18        44.7            7.39
# Geneva, AL                 10.52          51.80        41.8            3.49
# Greene, AL                  6.01          54.17        15.8            5.10
# Hale, AL                    6.96          53.35        24.7            9.94
# ...                          ...            ...         ...             ...
# Vernon, WI                 10.95          50.72        33.0           13.02
# Vilas, WI                  14.28          50.29        21.3           13.49
# Walworth, WI               11.08          50.76       139.9           13.82
# Washburn, WI               13.05          50.14        17.4           11.06
# Washington, WI              9.36          50.13       235.6            7.27
# Waukesha, WI               11.65          50.40       574.9            4.23
# Waupaca, WI                11.01          50.60        63.4           41.81
# Waushara, WI               11.64          50.33        32.1            8.01
# Winnebago, WI              12.44          50.87       330.4            8.32
# Wood, WI                   11.99          51.12        94.5           10.97
# Albany, WY                 10.98          48.26         7.2            3.99
# Big Horn, WY               13.07          49.95         3.4           17.10
# Campbell, WY               10.50          48.87         6.4            4.66
# Carbon, WY                 18.85          47.23         2.0            7.39
# Converse, WY               16.68          50.88         2.7            4.21
# Crook, WY                  13.48          49.77         1.9            5.93
# Fremont, WY                15.67          50.10         3.7            5.54
# Goshen, WY                 10.97          51.48         5.6            6.00
# Hot Springs, WY            16.36          50.61         2.3           14.89
# Johnson, WY                16.24          50.53         1.5            8.57
# Laramie, WY                13.56          50.12        28.1            2.64
# Natrona, WY                17.88          50.84        11.7            5.10
# Niobrara, WY               15.60          53.70         1.0           13.60
# Park, WY                   12.58          50.76         3.4            8.10
# Platte, WY                 22.71          50.48         3.9            5.24
# Sheridan, WY               16.59          50.73         9.5            4.67
# Sublette, WY               12.18          47.98         1.0            8.60
# Sweetwater, WY             14.64          49.42         3.9            3.00
# Washakie, WY               14.47          49.65         3.8            8.47
# Weston, WY                 13.94          49.90         2.8            6.21
#
#                  crimeIndex
# County
# Autauga, AL             457
# Baldwin, AL             282
# Barbour, AL              47
# Blount, AL              185
# Bullock, AL             141
# Butler, AL              266
# Calhoun, AL             560
# Chambers, AL            218
# Cherokee, AL             51
# Chilton, AL             296
# Choctaw, AL              29
# Clarke, AL              105
# Cleburne, AL            203
# Coffee, AL              357
# Colbert, AL             330
# Conecuh, AL             171
# Covington, AL           239
# Crenshaw, AL            165
# Cullman, AL             247
# Dale, AL                201
# Dallas, AL              794
# De Kalb, AL             104
# Elmore, AL              357
# Escambia, AL            161
# Etowah, AL              616
# Fayette, AL             113
# Franklin, AL             99
# Geneva, AL              142
# Greene, AL              416
# Hale, AL                122
# ...                     ...
# Vernon, WI              117
# Vilas, WI               315
# Walworth, WI            321
# Washburn, WI            221
# Washington, WI          343
# Waukesha, WI            278
# Waupaca, WI             317
# Waushara, WI            266
# Winnebago, WI           453
# Wood, WI                307
# Albany, WY              522
# Big Horn, WY            183
# Campbell, WY            479
# Carbon, WY              386
# Converse, WY            425
# Crook, WY               215
# Fremont, WY             440
# Goshen, WY              308
# Hot Springs, WY         366
# Johnson, WY             278
# Laramie, WY             486
# Natrona, WY             667
# Niobrara, WY            220
# Park, WY                361
# Platte, WY              200
# Sheridan, WY            275
# Sublette, WY            432
# Sweetwater, WY          625
# Washakie, WY            313
# Weston, WY              167
#
# [2704 rows x 10 columns]

# %% [markdown]
# # Q2: Predict percentVoting on all regressors

# %% [markdown]
# Run regression on percentVoting compared to all regressors to determine two worst regressors

# %%
y, X = dmatrices('percentVoting ~ medAge + meanSavings + Income + percentPoverty + percentVeterans + percentFemale + popDensity + percentNursing + crimeIndex', data=df, return_type='dataframe')
y[:3]
# Out:
#              percentVoting
# County
# Autauga, AL          30.92
# Baldwin, AL          26.24
# Barbour, AL          46.36

# %%
X[:3]
# Out:
#              Intercept  medAge  meanSavings   Income  percentPoverty  \
# County
# Autauga, AL        1.0    31.7      57623.0  15768.0            15.2
# Baldwin, AL        1.0    35.5      84935.0  16954.0            13.6
# Barbour, AL        1.0    32.8      83656.0  15532.0            25.0
#
#              percentVeterans  percentFemale  popDensity  percentNursing  \
# County
# Autauga, AL            10.74          51.41        60.4            2.36
# Baldwin, AL             9.73          51.34        66.5            5.40
# Barbour, AL             8.82          53.03        28.8            7.02
#
#              crimeIndex
# County
# Autauga, AL       457.0
# Baldwin, AL       282.0
# Barbour, AL        47.0

# %%
model = sm.OLS(y, X)       # Set up the model
result = model.fit()       # Fit model (find the intercept and slopes)
print result.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          percentVoting   R-squared:                       0.327
# Model:                            OLS   Adj. R-squared:                  0.325
# Method:                 Least Squares   F-statistic:                     145.4
# Date:                Tue, 10 Apr 2018   Prob (F-statistic):          4.12e-224
# Time:                        16:30:10   Log-Likelihood:                -9576.0
# No. Observations:                2704   AIC:                         1.917e+04
# Df Residuals:                    2694   BIC:                         1.923e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         -38.3094      5.818     -6.585      0.000     -49.717     -26.901
# medAge              0.0707      0.060      1.179      0.239      -0.047       0.188
# meanSavings     -3.077e-05   4.93e-06     -6.247      0.000   -4.04e-05   -2.11e-05
# Income              0.0002   7.42e-05      2.375      0.018    3.08e-05       0.000
# percentPoverty      0.7669      0.035     22.118      0.000       0.699       0.835
# percentVeterans     0.3088      0.087      3.554      0.000       0.138       0.479
# percentFemale       1.1844      0.119      9.985      0.000       0.952       1.417
# popDensity          0.0019      0.000      9.681      0.000       0.002       0.002
# percentNursing     -0.0908      0.033     -2.794      0.005      -0.155      -0.027
# crimeIndex         -0.0013      0.001     -1.469      0.142      -0.003       0.000
# ==============================================================================
# Omnibus:                       22.560   Durbin-Watson:                   1.360
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.526
# Skew:                           0.129   Prob(JB):                     6.39e-07
# Kurtosis:                       3.432   Cond. No.                     3.62e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.62e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## The two highest (and therefore worst) p-values are Median Age and Crime Index.

# %% [markdown]
# # Q3: Formula Writing Function

# %% [markdown]
# Function to create regression formula (vs percentVoting) given list of regressors

# %%
def formula(var):
    s = "percentVoting ~ "
    for i in var:
        s += i + " + "
    s = s[:-3]
    return s
    
formula(['medAge', 'meanSavings'])
# Out:
# 'percentVoting ~ medAge + meanSavings'

# %% [markdown]
# # Q4: R-Squared Function

# %% [markdown]
# Function to find r-squared value of regression (vs percentVoting) given list of regressors

# %%
def rsquared(var):
    y, X = dmatrices(formula(var), data=df, return_type='dataframe')
    model = sm.OLS(y, X)       # Set up the model
    result = model.fit()       # Fit model
    return result.rsquared
    
rsquared(['percentPoverty', 'popDensity'])
# Out:
# 0.28582980229105792

# %% [markdown]
# # Q5: Next Best Regressor

# %% [markdown]
# Function to determine best next regressor (and r-squared value) given list of all regressors and list of current regressors

# %%
def best_next_regressor(all_regressor_list, current_regressors_list):
    
    rsquared_list = []
    for i in all_regressor_list:
        current_regressors_list.append(i)
        rsq = rsquared(current_regressors_list)
        rsquared_list.append([i, rsq])
        current_regressors_list.pop()

    best_regressor = max([sublist[-1] for sublist in rsquared_list])
    for i in rsquared_list:
        if i[-1] == best_regressor:
            best_reg_name = i[0]

    return [best_reg_name, best_regressor]

best_next_regressor(['medAge', 'meanSavings', 'Income', 'percentPoverty', 'percentVeterans', 'percentFemale', 'popDensity', 'percentNursing', 'crimeIndex'], ['meanSavings', 'medAge'])
# Out:
# ['percentPoverty', 0.25366866974428481]

# %% [markdown]
# # Q6: k Best Regressors

# %% [markdown]
# Function to determine k best regressors given number of regressors and list of all regressors

# %%
def best_regressors(num_regressors, all_regressors_list):
    listofr = []
    rsq_list = []
    selected = []
    for i in range(num_regressors):
        bestr = best_next_regressor(all_regressors_list, selected)
        selected.append(bestr[0])
        rsq_list.append(bestr)
        rsq_list[i] = [formula(selected), bestr[1]]
    
    return rsq_list

best_regressors(4, ['medAge', 'meanSavings', 'Income', 'percentPoverty', 'percentVeterans', 'percentFemale', 'popDensity', 'percentNursing', 'crimeIndex'])
# Out:
# [['percentVoting ~ percentPoverty', 0.25103851961631951],
#  ['percentVoting ~ percentPoverty + popDensity', 0.28582980229105792],
#  ['percentVoting ~ percentPoverty + popDensity + percentFemale',
#   0.30914506632485794],
#  ['percentVoting ~ percentPoverty + popDensity + percentFemale + meanSavings',
#   0.31924118502370513]]

# %% [markdown]
# # Q7: Regressors in Best Order

# %% [markdown]
# Display all next best regressors in best order using forward selection

# %%
best_regressors(9, ['medAge', 'meanSavings', 'Income', 'percentPoverty', 'percentVeterans', 'percentFemale', 'popDensity', 'percentNursing', 'crimeIndex'])
# Out:
# [['percentVoting ~ percentPoverty', 0.25103851961631951],
#  ['percentVoting ~ percentPoverty + popDensity', 0.28582980229105792],
#  ['percentVoting ~ percentPoverty + popDensity + percentFemale',
#   0.30914506632485794],
#  ['percentVoting ~ percentPoverty + popDensity + percentFemale + meanSavings',
#   0.31924118502370513],
#  ['percentVoting ~ percentPoverty + popDensity + percentFemale + meanSavings + percentVeterans',
#   0.32299256887291694],
#  ['percentVoting ~ percentPoverty + popDensity + percentFemale + meanSavings + percentVeterans + percentNursing',
#   0.32485127138693681],
#  ['percentVoting ~ percentPoverty + popDensity + percentFemale + meanSavings + percentVeterans + percentNursing + Income',
#   0.32582492389958873],
#  ['percentVoting ~ percentPoverty + popDensity + percentFemale + meanSavings + percentVeterans + percentNursing + Income + crimeIndex',
#   0.32655325570492566],
#  ['percentVoting ~ percentPoverty + popDensity + percentFemale + meanSavings + percentVeterans + percentNursing + Income + crimeIndex + medAge',
#   0.32690038725174042]]

# %%
dfr = pd.DataFrame(best_regressors(9, ['medAge', 'meanSavings', 'Income', 'percentPoverty', 'percentVeterans', 'percentFemale', 'popDensity', 'percentNursing', 'crimeIndex']))
dfr.columns = ['Formula', 'R-Square']
dfr.set_index('Formula', inplace=True)
dfr
# Out:
#                                                     R-Square
# Formula
# percentVoting ~ percentPoverty                      0.251039
# percentVoting ~ percentPoverty + popDensity         0.285830
# percentVoting ~ percentPoverty + popDensity + p...  0.309145
# percentVoting ~ percentPoverty + popDensity + p...  0.319241
# percentVoting ~ percentPoverty + popDensity + p...  0.322993
# percentVoting ~ percentPoverty + popDensity + p...  0.324851
# percentVoting ~ percentPoverty + popDensity + p...  0.325825
# percentVoting ~ percentPoverty + popDensity + p...  0.326553
# percentVoting ~ percentPoverty + popDensity + p...  0.326900

# %% [markdown]
# # Q8: Plot R-Squared Values as Regressors are Added in Best Order

# %% [markdown]
# Plot best regressors

# %%
dfr.plot(kind='bar')
plt.ylabel('R-Square')
plt.xlabel('Regressor(s)')
plt.ylim((0.0,0.35))
# Out:
# (0.0, 0.35)

# %% [markdown]
# # Q9: Classification Target

# %% [markdown]
# Classification target = 1 if percentVoting >= 40% or 0 if percentVoting < 40% (apply mask)

# %%
# Create a new 'target' column with all 0
df['target'] = 0.0

# Mask the rows
mask = df['percentVoting'] >= 40
df.loc[mask, 'target'] = 1.0
df[:5]
# Out:
#              percentVoting  medAge  meanSavings  Income  percentPoverty  \
# County
# Autauga, AL          30.92    31.7        57623   15768            15.2
# Baldwin, AL          26.24    35.5        84935   16954            13.6
# Barbour, AL          46.36    32.8        83656   15532            25.0
# Blount, AL           32.92    34.5        61249   14820            15.0
# Bullock, AL          67.67    31.7        75725   11120            33.0
#
#              percentVeterans  percentFemale  popDensity  percentNursing  \
# County
# Autauga, AL            10.74          51.41        60.4            2.36
# Baldwin, AL             9.73          51.34        66.5            5.40
# Barbour, AL             8.82          53.03        28.8            7.02
# Blount, AL              9.67          51.15        62.4            2.36
# Bullock, AL             7.08          50.76        17.6            2.91
#
#              crimeIndex  target
# County
# Autauga, AL         457     0.0
# Baldwin, AL         282     0.0
# Barbour, AL          47     1.0
# Blount, AL          185     0.0
# Bullock, AL         141     1.0

# %% [markdown]
# # Q10: Training and Test Sets

# %% [markdown]
# Create design matrices for predicting target based on percentPoverty and popDensity; 70% training and 30% testing

# %%
Y, X = dmatrices('target ~ 0 + percentPoverty + popDensity',
                 df,return_type="dataframe")
print 'Design matrix X'
print X[:5]
print 'Outcomes Y'
print Y[:5]
# Out:
# Design matrix X
#              percentPoverty  popDensity
# County
# Autauga, AL            15.2        60.4
# Baldwin, AL            13.6        66.5
# Barbour, AL            25.0        28.8
# Blount, AL             15.0        62.4
# Bullock, AL            33.0        17.6
# Outcomes Y
#              target
# County
# Autauga, AL     0.0
# Baldwin, AL     0.0
# Barbour, AL     1.0
# Blount, AL      0.0
# Bullock, AL     1.0

# %%
y = Y['target'].values
print y[:5]
# Out:
# [ 0.  0.  1.  0.  1.]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
y_train[:5]
# Out:
# array([ 0.,  1.,  1.,  0.,  1.])

# %% [markdown]
# # Q11: Accuracy of Classification

# %% [markdown]
# Use k-nearest neighbor to determine accuracy of classification

# %%
from sklearn import neighbors
model_list = []
n_list = [1,3,5,10,20,50,100,1000]
for i in n_list:
    model = neighbors.KNeighborsClassifier(n_neighbors=i,
                                       weights='uniform',
                                       p=2)
    model_list.append(model)

# %%
fit_list = []
for i in model_list:
    fit = i.fit(X_train, y_train)
    fit_list.append(fit)

# %%
X_train.iloc[0:5]
# Out:
#              percentPoverty  popDensity
# County
# Coleman, TX            23.4         7.5
# Audubon, IA            11.4        16.0
# Lonoke, AR             14.2        53.4
# Oswego, NY             13.5       130.5
# Fayette, KY            15.8       816.2

# %%
for i in model_list:
    print 'Predictions =', i.predict(X_train.iloc[0:5])
# Out:
# Predictions = [ 0.  1.  1.  0.  1.]
# Predictions = [ 1.  0.  0.  0.  0.]
# Predictions = [ 0.  0.  0.  0.  1.]
# Predictions = [ 0.  0.  0.  0.  1.]
# Predictions = [ 0.  0.  0.  0.  1.]
# Predictions = [ 0.  0.  0.  0.  1.]
# Predictions = [ 0.  0.  0.  0.  1.]
# Predictions = [ 0.  0.  1.  0.  0.]

# %%
from sklearn import metrics
for i in model_list:
    prediction_on_training = i.predict(X_train)
    predicted_classes = i.predict(X_test)
    print i.n_neighbors, "Nearest Neigbor(s)\t\t", metrics.accuracy_score(y_train, prediction_on_training), "Train Accuracy\t\t", metrics.accuracy_score(y_test, predicted_classes), "Test Accuracy"
# Out:
# 1 Nearest Neigbor(s)		0.997885835095 Train Accuracy		0.600985221675 Test Accuracy
# 3 Nearest Neigbor(s)		0.788054968288 Train Accuracy		0.635467980296 Test Accuracy
# 5 Nearest Neigbor(s)		0.748414376321 Train Accuracy		0.630541871921 Test Accuracy
# 10 Nearest Neigbor(s)		0.720401691332 Train Accuracy		0.646551724138 Test Accuracy
# 20 Nearest Neigbor(s)		0.690274841438 Train Accuracy		0.658866995074 Test Accuracy
# 50 Nearest Neigbor(s)		0.683932346723 Train Accuracy		0.662561576355 Test Accuracy
# 100 Nearest Neigbor(s)		0.677589852008 Train Accuracy		0.663793103448 Test Accuracy
# 1000 Nearest Neigbor(s)		0.567124735729 Train Accuracy		0.576354679803 Test Accuracy

# %% [markdown]
# # Q12: Plots and Reasons

# %% [markdown]
# Scatter plot of popDensity vs percentPoverty

# %%
sc = scatter(X['percentPoverty'], X['popDensity'], c=y, cmap='bwr')
colorbar(sc)
xlabel('Percent Poverty')
ylabel('Population Density')
# Out:
# Text(0,0.5,u'Population Density')

# %% [markdown]
# People who voted for Bill Clinton are mostly from counties that have medium to high poverty and low to medium population density
